# %% [markdown]
# # POC of hyperparameter tuning with Optuna on scVI

# %%
import os
import sys
import pandas as pd
import optuna
import jax
import scvi

import anndata as ad
from scib_metrics.benchmark import Benchmarker, BioConservation, BatchCorrection
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import optuna
#       5 import jax
# ----> 6 import scvi
#       8 import anndata as ad
#       9 from scib_metrics.benchmark import Benchmarker, BioConservation, BatchCorrection
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/__init__.py:7
#       4 import logging
#       6 from ._constants import _CONSTANTS
# ----> 7 from ._settings import settings
#       9 # this import needs to come after prior imports to prevent circular import
#      10 from . import data, model, external, utils
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/_settings.py:5
#       2 from pathlib import Path
#       3 from typing import Union
# ----> 5 import pytorch_lightning as pl
#       6 import torch
#       7 from rich.console import Console
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/pytorch_lightning/__init__.py:20
#      17 _PACKAGE_ROOT = os.path.dirname(__file__)
#      18 _PROJECT_ROOT = os.path.dirname(_PACKAGE_ROOT)
# ---> 20 from pytorch_lightning import metrics  # noqa: E402
#      21 from pytorch_lightning.callbacks import Callback  # noqa: E402
#      22 from pytorch_lightning.core import LightningDataModule, LightningModule  # noqa: E402
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/pytorch_lightning/metrics/__init__.py:15
#       1 # Copyright The PyTorch Lightning team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from pytorch_lightning.metrics.classification import (  # noqa: F401
#      16     Accuracy,
#      17     AUC,
#      18     AUROC,
#      19     AveragePrecision,
#      20     ConfusionMatrix,
#      21     F1,
#      22     FBeta,
#      23     HammingDistance,
#      24     IoU,
#      25     Precision,
#      26     PrecisionRecallCurve,
#      27     Recall,
#      28     ROC,
#      29     StatScores,
#      30 )
#      31 from pytorch_lightning.metrics.metric import Metric, MetricCollection  # noqa: F401
#      32 from pytorch_lightning.metrics.regression import (  # noqa: F401
#      33     ExplainedVariance,
#      34     MeanAbsoluteError,
#    (...)     39     SSIM,
#      40 )
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/pytorch_lightning/metrics/classification/__init__.py:14
#       1 # Copyright The PyTorch Lightning team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from pytorch_lightning.metrics.classification.accuracy import Accuracy  # noqa: F401
#      15 from pytorch_lightning.metrics.classification.auc import AUC  # noqa: F401
#      16 from pytorch_lightning.metrics.classification.auroc import AUROC  # noqa: F401
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/pytorch_lightning/metrics/classification/accuracy.py:18
#      14 from typing import Any, Callable, Optional
#      16 from torchmetrics import Accuracy as _Accuracy
# ---> 18 from pytorch_lightning.metrics.utils import deprecated_metrics
#      21 class Accuracy(_Accuracy):
#      23     @deprecated_metrics(target=_Accuracy)
#      24     def __init__(
#      25         self,
#    (...)     32         dist_sync_fn: Callable = None,
#      33     ):
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/pytorch_lightning/metrics/utils.py:22
#      20 from torchmetrics.utilities.data import dim_zero_mean as _dim_zero_mean
#      21 from torchmetrics.utilities.data import dim_zero_sum as _dim_zero_sum
# ---> 22 from torchmetrics.utilities.data import get_num_classes as _get_num_classes
#      23 from torchmetrics.utilities.data import select_topk as _select_topk
#      24 from torchmetrics.utilities.data import to_categorical as _to_categorical
#
# ImportError: cannot import name 'get_num_classes' from 'torchmetrics.utilities.data' (/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/torchmetrics/utilities/data.py)

# %%
for pkg in [jax]:
    print(f'{pkg.__name__}: {pkg.__version__}')
# Out:
# jax: 0.4.35

# %% [markdown]
# ## Load data

# %%
data_path = "/home/icb/tim.treis/projects/broad_integrate/2023_Arevalo_BatchCorrection/outputs/scenario_7/mad_int_featselect.parquet"

data = pd.read_parquet(data_path)
metadata_cols = data.filter(regex="Metadata").columns

adata = ad.AnnData(X=data.drop(metadata_cols, axis=1).values, obs=data[metadata_cols])
adata
# Out:
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 25329 × 1018
#     obs: 'Metadata_Source', 'Metadata_Plate', 'Metadata_Well', 'Metadata_JCP2022', 'Metadata_InChIKey', 'Metadata_InChI', 'Metadata_Batch', 'Metadata_PlateType', 'Metadata_PertType', 'Metadata_Row', 'Metadata_Column', 'Metadata_Microscope'

# %% [markdown]
# ## Define Optuna trials and evaluation logic

# %%
def scib_benchmark_embedding(
    adata: ad.AnnData,
    batch_key: str,
    label_key: str,
) -> float:
    adata.obsm["trial"] = adata.X

    # silence output
    sys.stdout = open(os.devnull, "w")

    bm = Benchmarker(
        adata=adata,
        batch_key=batch_key,
        label_key=label_key,
        embedding_obsm_keys=["trial"],
        bio_conservation_metrics=BioConservation(),
        batch_correction_metrics=BatchCorrection(),
    )
    bm.benchmark()
    df = bm.get_results(min_max_scale=False)

    # restore output
    sys.stdout.close()
    sys.stdout = sys.__stdout__

    return df.loc["trial"][["Batch correction", "Bio conservation"]].values


def objective(
    trial,
    adata: ad.AnnData,
    batch_key: str,
    label_key: str,
    smoketest: bool = True,
):
    # Silence output during training and evaluation
    sys.stdout = open(os.devnull, "w")

    # Optimize scVI hyperparameters:
    n_hidden = trial.suggest_int("n_hidden", 64, 256, step=64)
    n_latent = trial.suggest_int("n_latent", 10, 100)
    n_layers = trial.suggest_int("n_layers", 1, 3)
    dropout_rate = trial.suggest_float("dropout_rate", 0.0, 0.5)
    # learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-2, log=True)
    n_epochs = 2 if smoketest else trial.suggest_int("n_epochs", 50, 200)

    # Preprocess data: subtract the minimum to ensure non-negative values (if needed)
    min_value = adata.X.min()
    adata.X -= min_value

    scvi.model.SCVI.setup_anndata(
        adata,
        batch_key=batch_key,
        labels_key=label_key,
        categorical_covariate_keys=["Metadata_Batch"],
    )
    vae = scvi.model.SCVI(
        adata,
        n_hidden=n_hidden,
        n_latent=n_latent,
        n_layers=n_layers,
        dropout_rate=dropout_rate,
    )

    vae.train(
        max_epochs=n_epochs,
        early_stopping=True,
        early_stopping_monitor="elbo_validation",
    )

    vals = vae.get_latent_representation()
    features = [f"scvi_{i}" for i in range(vals.shape[1])]
    integrated_adata = ad.AnnData(
        X=pd.DataFrame(vals, columns=features, index=adata.obs_names),
        obs=adata.obs.copy()
    )

    batch_score, bio_score = scib_benchmark_embedding(
        adata=integrated_adata,
        batch_key=batch_key,
        label_key=label_key,
    )

    sys.stdout.close()
    sys.stdout = sys.__stdout__

    return batch_score, bio_score

batch_key = "Metadata_Source"
label_key = "Metadata_JCP2022"

study = optuna.create_study(directions=["maximize", "maximize"])
study.optimize(lambda trial: objective(trial, adata.copy(), batch_key, label_key), n_trials=2)
# Out:
# [I 2025-03-24 15:38:33,463] A new study created in memory with name: no-name-7e2f09da-cd03-4adb-a96b-00a0c1d5e332
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/data/fields/_base_field.py:63: UserWarning: adata.X does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# SLURM auto-requeueing enabled. Setting signal handlers.
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/module/_vae.py:569: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/module/_vae.py:569: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/module/_vae.py:569: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scvi/module/_vae.py:569: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# `Trainer.fit` stopped: `max_epochs=2` reached.
# /home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scanpy/preprocessing/_pca/__init__.py:439: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
# Computing neighbors: 100%|██████████| 1/1 [00:33<00:00, 33.35s/it]
# Embeddings:   0%|          | 0/1 [00:00<?, ?it/s]ERROR:jax._src.xla_bridge:Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 610, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax_plugins/xla_cuda12/__init__.py", line 97, in initialize
#     xla_client.register_custom_type_id_handler(
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jaxlib.xla_client' has no attribute 'register_custom_type_id_handler'
# Embeddings:   0%|          | 0/1 [00:08<?, ?it/s]
# [W 2025-03-24 15:40:22,561] Trial 0 failed with parameters: {'n_hidden': 256, 'n_latent': 64, 'n_layers': 1, 'dropout_rate': 0.4309920974772833} because of the following error: RuntimeError("Unable to initialize backend 'cuda': INVALID_ARGUMENT: Unexpected PJRT_Client_Create_Args size: expected 88, got 72. The plugin is likely built with a later version than the framework. This plugin is built with PJRT API version 0.67. (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)").
# Traceback (most recent call last):
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 896, in backends
#     backend = _init_backend(platform)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 982, in _init_backend
#     backend = registration.factory()
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 674, in factory
#     return xla_client.make_c_api_client(plugin_name, updated_options, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jaxlib/xla_client.py", line 202, in make_c_api_client
#     return _xla.get_c_api_client(plugin_name, options, distributed_client)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# jaxlib.xla_extension.XlaRuntimeError: INVALID_ARGUMENT: Unexpected PJRT_Client_Create_Args size: expected 88, got 72. The plugin is likely built with a later version than the framework. This plugin is built with PJRT API version 0.67.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_2913662/707081402.py", line 88, in <lambda>
#     study.optimize(lambda trial: objective(trial, adata.copy(), batch_key, label_key), n_trials=2)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_2913662/707081402.py", line 73, in objective
#     batch_score, bio_score = scib_benchmark_embedding(
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_2913662/707081402.py", line 19, in scib_benchmark_embedding
#     bm.benchmark()
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py", line 241, in benchmark
#     metric_value = getattr(MetricAnnDataAPI, metric_name)(ad, metric_fn)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py", line 85, in <lambda>
#     isolated_labels = lambda ad, fn: fn(ad.X, ad.obs[_LABELS], ad.obs[_BATCH])
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/metrics/_isolated_labels.py", line 48, in isolated_labels
#     silhouette_all = silhouette_samples(X, labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/utils/_silhouette.py", line 98, in silhouette_samples
#     labels = jnp.asarray(labels)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py", line 5592, in asarray
#     return array(a, dtype=dtype, copy=bool(copy), order=order, device=device)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py", line 5346, in array
#     return jax.device_put(object)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/api.py", line 2291, in device_put
#     out_flat = dispatch.device_put_p.bind(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/core.py", line 438, in bind
#     return self.bind_with_trace(find_top_trace(args), args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/core.py", line 442, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/core.py", line 955, in process_primitive
#     return primitive.impl(*tracers, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/dispatch.py", line 534, in _batched_device_put_impl
#     y = _device_put_impl(x, device=device, src=src, copy=cp)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/dispatch.py", line 523, in _device_put_impl
#     return _device_put_sharding_impl(x, aval, device, copy)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/dispatch.py", line 482, in _device_put_sharding_impl
#     sh = SingleDeviceSharding(pxla._get_default_device()
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py", line 1716, in _get_default_device
#     return config.default_device.value or xb.local_devices()[0]
#                                           ^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 1152, in local_devices
#     process_index = get_backend(backend).process_index()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 1028, in get_backend
#     return _get_backend_uncached(platform)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 1007, in _get_backend_uncached
#     bs = backends()
#          ^^^^^^^^^^
#   File "/home/icb/tim.treis/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 912, in backends
#     raise RuntimeError(err_msg)
# RuntimeError: Unable to initialize backend 'cuda': INVALID_ARGUMENT: Unexpected PJRT_Client_Create_Args size: expected 88, got 72. The plugin is likely built with a later version than the framework. This plugin is built with PJRT API version 0.67. (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)
# [W 2025-03-24 15:40:22,703] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:896, in backends()
#     894   continue
# --> 896 backend = _init_backend(platform)
#     897 _backends[platform] = backend
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:982, in _init_backend(platform)
#     981 logger.debug("Initializing backend '%s'", platform)
# --> 982 backend = registration.factory()
#     983 # TODO(skye): consider raising more descriptive errors directly from backend
#     984 # factories instead of returning None.
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:674, in register_plugin.<locals>.factory()
#     673 if distributed.global_state.client is None:
# --> 674   return xla_client.make_c_api_client(plugin_name, updated_options, None)
#     676 distribute_options = {
#     677     'node_id': distributed.global_state.process_id,
#     678     'num_nodes': distributed.global_state.num_processes,
#     679 }
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jaxlib/xla_client.py:202, in make_c_api_client(plugin_name, options, distributed_client)
#     201   options = {}
# --> 202 return _xla.get_c_api_client(plugin_name, options, distributed_client)
#
# XlaRuntimeError: INVALID_ARGUMENT: Unexpected PJRT_Client_Create_Args size: expected 88, got 72. The plugin is likely built with a later version than the framework. This plugin is built with PJRT API version 0.67.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 88
#      85 label_key = "Metadata_JCP2022"
#      87 study = optuna.create_study(directions=["maximize", "maximize"])
# ---> 88 study.optimize(lambda trial: objective(trial, adata.copy(), batch_key, label_key), n_trials=2)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)    382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[4], line 88, in <lambda>(trial)
#      85 label_key = "Metadata_JCP2022"
#      87 study = optuna.create_study(directions=["maximize", "maximize"])
# ---> 88 study.optimize(lambda trial: objective(trial, adata.copy(), batch_key, label_key), n_trials=2)
#
# Cell In[4], line 73, in objective(trial, adata, batch_key, label_key, smoketest)
#      67 features = [f"scvi_{i}" for i in range(vals.shape[1])]
#      68 integrated_adata = ad.AnnData(
#      69     X=pd.DataFrame(vals, columns=features, index=adata.obs_names),
#      70     obs=adata.obs.copy()
#      71 )
# ---> 73 batch_score, bio_score = scib_benchmark_embedding(
#      74     adata=integrated_adata,
#      75     batch_key=batch_key,
#      76     label_key=label_key,
#      77 )
#      79 sys.stdout.close()
#      80 sys.stdout = sys.__stdout__
#
# Cell In[4], line 19, in scib_benchmark_embedding(adata, batch_key, label_key)
#       9 sys.stdout = open(os.devnull, "w")
#      11 bm = Benchmarker(
#      12     adata=adata,
#      13     batch_key=batch_key,
#    (...)     17     batch_correction_metrics=BatchCorrection(),
#      18 )
# ---> 19 bm.benchmark()
#      20 df = bm.get_results(min_max_scale=False)
#      22 # restore output
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py:241, in Benchmarker.benchmark(self)
#     238 if isinstance(use_metric_or_kwargs, dict):
#     239     # Kwargs in this case
#     240     metric_fn = partial(metric_fn, **use_metric_or_kwargs)
# --> 241 metric_value = getattr(MetricAnnDataAPI, metric_name)(ad, metric_fn)
#     242 # nmi/ari metrics return a dict
#     243 if isinstance(metric_value, dict):
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py:85, in MetricAnnDataAPI.<lambda>(ad, fn)
#      82 class MetricAnnDataAPI(Enum):
#      83     """Specification of the AnnData API for a metric."""
# ---> 85     isolated_labels = lambda ad, fn: fn(ad.X, ad.obs[_LABELS], ad.obs[_BATCH])
#      86     nmi_ari_cluster_labels_leiden = lambda ad, fn: fn(ad.uns["15_neighbor_res"], ad.obs[_LABELS])
#      87     nmi_ari_cluster_labels_kmeans = lambda ad, fn: fn(ad.X, ad.obs[_LABELS])
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/metrics/_isolated_labels.py:48, in isolated_labels(X, labels, batch, rescale, iso_threshold)
#      45 scores = {}
#      46 isolated_labels = _get_isolated_labels(labels, batch, iso_threshold)
# ---> 48 silhouette_all = silhouette_samples(X, labels)
#      49 if rescale:
#      50     silhouette_all = (silhouette_all + 1) / 2
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/scib_metrics/utils/_silhouette.py:98, in silhouette_samples(X, labels, chunk_size)
#      96     raise ValueError("X and labels should have the same number of samples")
#      97 labels = pd.Categorical(labels).codes
# ---> 98 labels = jnp.asarray(labels)
#      99 label_freqs = jnp.bincount(labels)
#     100 reduce_fn = partial(_silhouette_reduce, labels=labels, label_freqs=label_freqs)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:5592, in asarray(a, dtype, order, copy, device)
#    5590 if dtype is not None:
#    5591   dtype = dtypes.canonicalize_dtype(dtype, allow_extended_dtype=True)  # type: ignore[assignment]
# -> 5592 return array(a, dtype=dtype, copy=bool(copy), order=order, device=device)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:5346, in array(object, dtype, copy, order, ndmin, device)
#    5341 # Use device_put to avoid a copy for ndarray inputs.
#    5342 if (not copy and isinstance(object, np.ndarray) and
#    5343     (dtype is None or dtype == object.dtype) and (ndmin <= object.ndim) and
#    5344     device is None):
#    5345   # Keep the output uncommitted.
# -> 5346   return jax.device_put(object)
#    5348 # For Python scalar literals, call coerce_to_array to catch any overflow
#    5349 # errors. We don't use dtypes.is_python_scalar because we don't want this
#    5350 # triggering for traced values. We do this here because it matters whether or
#    5351 # not dtype is None. We don't assign the result because we want the raw object
#    5352 # to be used for type inference below.
#    5353 if isinstance(object, (bool, int, float, complex)):
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/api.py:2291, in device_put(x, device, src, donate, may_alias)
#    2289 for xf, d in zip(x_flat, device_flat):  # type: ignore
#    2290   _check_sharding(shaped_abstractify(xf), d)
# -> 2291 out_flat = dispatch.device_put_p.bind(
#    2292     *x_flat, devices=device_flat, srcs=src_flat,
#    2293     copy_semantics=copy_semantics)
#    2294 return tree_unflatten(treedef, out_flat)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/core.py:438, in Primitive.bind(self, *args, **params)
#     435 def bind(self, *args, **params):
#     436   assert (not config.enable_checks.value or
#     437           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 438   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/core.py:955, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     953   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     954 else:
# --> 955   return primitive.impl(*tracers, **params)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/dispatch.py:534, in _batched_device_put_impl(devices, srcs, copy_semantics, *xs)
#     532 shard_arg_indices, shard_arg_xs, shard_arg_shardings = [], [], []
#     533 for i, (x, device, src, cp) in enumerate(zip(xs, devices, srcs, copy_semantics)):
# --> 534   y = _device_put_impl(x, device=device, src=src, copy=cp)
#     535   if isinstance(y, _DeferredShardArg):
#     536     shard_arg_indices.append(i)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/dispatch.py:523, in _device_put_impl(x, device, src, copy)
#     518     return _device_put_sharding_impl(x, aval, l.sharding, copy)
#     519   return api.jit(
#     520       _identity_fn, out_shardings=l,
#     521       donate_argnums=(0 if copy == CopySemantics.DONATE else None))(x)
# --> 523 return _device_put_sharding_impl(x, aval, device, copy)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/dispatch.py:482, in _device_put_sharding_impl(x, aval, device, copy)
#     478     device = x.sharding._device_assignment[0] if device is None else device
#     479     return pxla.batched_device_put(aval, SingleDeviceSharding(device), [x],
#     480                                    [device])
# --> 482 sh = SingleDeviceSharding(pxla._get_default_device()
#     483                           if device is None else device)
#     484 return _DeferredShardArg(x, sh, aval, device is not None)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1716, in _get_default_device()
#    1715 def _get_default_device() -> xc.Device:
# -> 1716   return config.default_device.value or xb.local_devices()[0]
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:1152, in local_devices(process_index, backend, host_id)
#    1150   process_index = host_id
#    1151 if process_index is None:
# -> 1152   process_index = get_backend(backend).process_index()
#    1153 if not (0 <= process_index < process_count(backend)):
#    1154   raise ValueError(f"Unknown process_index {process_index}")
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:1028, in get_backend(platform)
#    1024 @lru_cache(maxsize=None)  # don't use util.memoize because there is no X64 dependence.
#    1025 def get_backend(
#    1026     platform: None | str | xla_client.Client = None
#    1027 ) -> xla_client.Client:
# -> 1028   return _get_backend_uncached(platform)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:1007, in _get_backend_uncached(platform)
#    1003   return platform
#    1005 platform = (platform or _XLA_BACKEND.value or _PLATFORM_NAME.value or None)
# -> 1007 bs = backends()
#    1008 if platform is not None:
#    1009   platform = canonicalize_platform(platform)
#
# File ~/miniconda/envs/scverse/envs/myenv/lib/python3.11/site-packages/jax/_src/xla_bridge.py:912, in backends()
#     910       else:
#     911         err_msg += " (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)"
# --> 912       raise RuntimeError(err_msg)
#     914 assert _default_backend is not None
#     915 if not config.jax_platforms.value:
#
# RuntimeError: Unable to initialize backend 'cuda': INVALID_ARGUMENT: Unexpected PJRT_Client_Create_Args size: expected 88, got 72. The plugin is likely built with a later version than the framework. This plugin is built with PJRT API version 0.67. (you may need to uninstall the failing plugin package, or set JAX_PLATFORMS=cpu to skip this backend.)

# %%
# !pip install --upgrade jax jaxlib

# %%
study.best_trials
# Out:
# []
